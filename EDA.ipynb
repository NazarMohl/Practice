# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Shows all columns in dataframe
pd.set_option('display.max_columns', None)

# %%
df_info = pd.ExcelFile("./consumption_monthly_NM_220921.xlsx")
df_sheetnames = df_info.sheet_names
df_sheetnames
# Out:
# ['2001-2006_FINAL',
#  '2007-2011_FINAL',
#  '2012_Final',
#  '2013_Final',
#  '2014_Final',
#  '2015_Final',
#  '2016_Final',
#  '2017_Final',
#  '2018_Final',
#  '2019_Final',
#  '2020_Final',
#  '2021_Preliminary',
#  '2022_Preliminary',
#  'EnergySource_Notes',
#  'NM Notes',
#  'Headers']

# %%
df_sheetnames[1]
# Out:
# '2007-2011_FINAL'

# %%
df_dict = {}
for sheet in df_sheetnames:
    df_dict[sheet] = pd.read_excel("./consumption_monthly_NM_220921.xlsx", sheet_name = sheet)

# %%
df_dict['2007-2011_FINAL']
# Out:
#        YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 0      2007      1    AK                     Total Electric Power Industry
# 1      2007      1    AK                     Total Electric Power Industry
# 2      2007      1    AK                     Total Electric Power Industry
# 3      2007      1    AK           Electric Generators, Electric Utilities
# 4      2007      1    AK           Electric Generators, Electric Utilities
# ...     ...    ...   ...                                               ...
# 47457  2011     12    WY  Electric Generators, Independent Power Producers
# 47458  2011     12    WY                     Total Electric Power Industry
# 47459  2011     12    WY                     Total Electric Power Industry
# 47460  2011     12    WY                     Total Electric Power Industry
# 47461  2011     12    WY                     Total Electric Power Industry
#
#       ENERGY SOURCE              (UNITS)  CONSUMPTION
# 0                      Coal (Short Tons)     45277.00
# 1                    Petroleum (Barrels)    131715.00
# 2                      Natural Gas (Mcf)   3928812.00
# 3                      Coal (Short Tons)     17695.00
# 4                    Petroleum (Barrels)    111483.00
# ...                                  ...          ...
# 47457                  Natural Gas (Mcf)      8096.00
# 47458                  Coal (Short Tons)   2596524.00
# 47459                  Natural Gas (Mcf)    304415.00
# 47460          Other Gases (Billion Btu)       172.16
# 47461                Petroleum (Barrels)      6687.00
#
# [47462 rows x 6 columns]

# %%
df_dict[df_sheetnames[1]]["STATE"]
# Out:
# 0        AK
# 1        AK
# 2        AK
# 3        AK
# 4        AK
#          ..
# 47457    WY
# 47458    WY
# 47459    WY
# 47460    WY
# 47461    WY
# Name: STATE, Length: 47462, dtype: object

# %%
df_dict[df_sheetnames[1]].loc[df_dict[df_sheetnames[1]]["STATE"] == "MD"]
# Out:
#        YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 296    2007      1    MD                     Total Electric Power Industry
# 297    2007      1    MD                     Total Electric Power Industry
# 298    2007      1    MD                     Total Electric Power Industry
# 299    2007      1    MD                     Total Electric Power Industry
# 300    2007      1    MD           Electric Generators, Electric Utilities
# ...     ...    ...   ...                                               ...
# 41793  2011     12    MD  Electric Generators, Independent Power Producers
# 41794  2011     12    MD                     Total Electric Power Industry
# 41795  2011     12    MD                     Total Electric Power Industry
# 41796  2011     12    MD                     Total Electric Power Industry
# 41797  2011     12    MD                     Total Electric Power Industry
#
#       ENERGY SOURCE              (UNITS)  CONSUMPTION
# 296                    Coal (Short Tons)   1095532.00
# 297                  Petroleum (Barrels)    107089.00
# 298                    Natural Gas (Mcf)    659234.00
# 299            Other Gases (Billion BTU)       356.46
# 300                  Petroleum (Barrels)      2669.00
# ...                                  ...          ...
# 41793                Petroleum (Barrels)     45889.00
# 41794                  Coal (Short Tons)    553983.00
# 41795                  Natural Gas (Mcf)    816158.00
# 41796          Other Gases (Billion Btu)       153.78
# 41797                Petroleum (Barrels)     47947.00
#
# [1129 rows x 6 columns]

# %%
sheet = '2007-2011_FINAL'
df_dict[sheet].loc[df_dict[sheet]["STATE"] == "MD"]
# Out:
#        YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 296    2007      1    MD                     Total Electric Power Industry
# 297    2007      1    MD                     Total Electric Power Industry
# 298    2007      1    MD                     Total Electric Power Industry
# 299    2007      1    MD                     Total Electric Power Industry
# 300    2007      1    MD           Electric Generators, Electric Utilities
# ...     ...    ...   ...                                               ...
# 41793  2011     12    MD  Electric Generators, Independent Power Producers
# 41794  2011     12    MD                     Total Electric Power Industry
# 41795  2011     12    MD                     Total Electric Power Industry
# 41796  2011     12    MD                     Total Electric Power Industry
# 41797  2011     12    MD                     Total Electric Power Industry
#
#       ENERGY SOURCE              (UNITS)  CONSUMPTION
# 296                    Coal (Short Tons)   1095532.00
# 297                  Petroleum (Barrels)    107089.00
# 298                    Natural Gas (Mcf)    659234.00
# 299            Other Gases (Billion BTU)       356.46
# 300                  Petroleum (Barrels)      2669.00
# ...                                  ...          ...
# 41793                Petroleum (Barrels)     45889.00
# 41794                  Coal (Short Tons)    553983.00
# 41795                  Natural Gas (Mcf)    816158.00
# 41796          Other Gases (Billion Btu)       153.78
# 41797                Petroleum (Barrels)     47947.00
#
# [1129 rows x 6 columns]

# %%
df_md = pd.DataFrame()
df_md
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for sheet in df_sheetnames:
    if sheet[0:2] == '20':
        print(sheet)
        df_md = df_dict[sheet].loc[df_dict[sheet]["STATE"] == "MD"]
# Out:
# 2001-2006_FINAL
# 2007-2011_FINAL
# 2012_Final
# 2013_Final
# 2014_Final
# 2015_Final
# 2016_Final
# 2017_Final
# 2018_Final
# 2019_Final
# 2020_Final
# 2021_Preliminary
# 2022_Preliminary

# %%
df_md
# Out:
#       YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 279   2022      1    MD                     Total Electric Power Industry
# 280   2022      1    MD                     Total Electric Power Industry
# 281   2022      1    MD                     Total Electric Power Industry
# 282   2022      1    MD         Combined Heat and Power, Industrial Power
# 283   2022      1    MD         Combined Heat and Power, Industrial Power
# ...    ...    ...   ...                                               ...
# 4110  2022      6    MD  Electric Generators, Independent Power Producers
# 4111  2022      6    MD  Electric Generators, Independent Power Producers
# 4112  2022      6    MD  Electric Generators, Independent Power Producers
# 4113  2022      6    MD           Electric Generators, Electric Utilities
# 4114  2022      6    MD           Electric Generators, Electric Utilities
#
#             ENERGY SOURCE  CONSUMPTION
# 279     Coal (Short Tons)       456613
# 280     Natural Gas (Mcf)      5578513
# 281   Petroleum (Barrels)        44009
# 282     Natural Gas (Mcf)        17224
# 283   Petroleum (Barrels)            0
# ...                   ...          ...
# 4110    Coal (Short Tons)       143592
# 4111    Natural Gas (Mcf)      7236472
# 4112  Petroleum (Barrels)        34075
# 4113    Natural Gas (Mcf)      3125789
# 4114  Petroleum (Barrels)          598
#
# [96 rows x 6 columns]

# %%
# !pwd
# Out:
# /c/Users/NM/Documents/2_Training/Practice

# %%
idmy = 0

# %%
idmy
# Out:
# 0
