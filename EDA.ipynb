# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Shows all columns in dataframe
pd.set_option('display.max_columns', None)

# %%
df_info = pd.ExcelFile("./consumption_monthly_NM_221001.xlsx")
df_sheetnames = df_info.sheet_names
df_sheetnames
# Out:
# ['2001-2006_FINAL',
#  '2007-2011_FINAL',
#  '2012_Final',
#  '2013_Final',
#  '2014_Final',
#  '2015_Final',
#  '2016_Final',
#  '2017_Final',
#  '2018_Final',
#  '2019_Final',
#  '2020_Final',
#  '2021_Preliminary',
#  '2022_Preliminary',
#  'EnergySource_Notes',
#  'NM Notes',
#  'Headers']

# %%
df_sheetnames[1]
# Out:
# '2007-2011_FINAL'

# %%
df_dict = {}
for sheet in df_sheetnames:
    df_dict[sheet] = pd.read_excel("./consumption_monthly_NM_221001.xlsx", sheet_name = sheet)

# %%
df_dict['2007-2011_FINAL']
# Out:
#        YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 0      2007      1    AK                     Total Electric Power Industry
# 1      2007      1    AK                     Total Electric Power Industry
# 2      2007      1    AK                     Total Electric Power Industry
# 3      2007      1    AK           Electric Generators, Electric Utilities
# 4      2007      1    AK           Electric Generators, Electric Utilities
# ...     ...    ...   ...                                               ...
# 47457  2011     12    WY  Electric Generators, Independent Power Producers
# 47458  2011     12    WY                     Total Electric Power Industry
# 47459  2011     12    WY                     Total Electric Power Industry
# 47460  2011     12    WY                     Total Electric Power Industry
# 47461  2011     12    WY                     Total Electric Power Industry
#
#                    ENERGY SOURCE  CONSUMPTION
# 0              Coal (Short Tons)     45277.00
# 1            Petroleum (Barrels)    131715.00
# 2              Natural Gas (Mcf)   3928812.00
# 3              Coal (Short Tons)     17695.00
# 4            Petroleum (Barrels)    111483.00
# ...                          ...          ...
# 47457          Natural Gas (Mcf)      8096.00
# 47458          Coal (Short Tons)   2596524.00
# 47459          Natural Gas (Mcf)    304415.00
# 47460  Other Gases (Billion Btu)       172.16
# 47461        Petroleum (Barrels)      6687.00
#
# [47462 rows x 6 columns]

# %%
df_dict[df_sheetnames[1]]["STATE"]
# Out:
# 0        AK
# 1        AK
# 2        AK
# 3        AK
# 4        AK
#          ..
# 47457    WY
# 47458    WY
# 47459    WY
# 47460    WY
# 47461    WY
# Name: STATE, Length: 47462, dtype: object

# %%
df_dict[df_sheetnames[1]].loc[df_dict[df_sheetnames[1]]["STATE"] == "MD"]
# Out:
#        YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 296    2007      1    MD                     Total Electric Power Industry
# 297    2007      1    MD                     Total Electric Power Industry
# 298    2007      1    MD                     Total Electric Power Industry
# 299    2007      1    MD                     Total Electric Power Industry
# 300    2007      1    MD           Electric Generators, Electric Utilities
# ...     ...    ...   ...                                               ...
# 41793  2011     12    MD  Electric Generators, Independent Power Producers
# 41794  2011     12    MD                     Total Electric Power Industry
# 41795  2011     12    MD                     Total Electric Power Industry
# 41796  2011     12    MD                     Total Electric Power Industry
# 41797  2011     12    MD                     Total Electric Power Industry
#
#                    ENERGY SOURCE  CONSUMPTION
# 296            Coal (Short Tons)   1095532.00
# 297          Petroleum (Barrels)    107089.00
# 298            Natural Gas (Mcf)    659234.00
# 299    Other Gases (Billion BTU)       356.46
# 300          Petroleum (Barrels)      2669.00
# ...                          ...          ...
# 41793        Petroleum (Barrels)     45889.00
# 41794          Coal (Short Tons)    553983.00
# 41795          Natural Gas (Mcf)    816158.00
# 41796  Other Gases (Billion Btu)       153.78
# 41797        Petroleum (Barrels)     47947.00
#
# [1129 rows x 6 columns]

# %%
sheet = '2007-2011_FINAL'
df_dict[sheet].loc[df_dict[sheet]["STATE"] == "MD"]
# Out:
#        YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 296    2007      1    MD                     Total Electric Power Industry
# 297    2007      1    MD                     Total Electric Power Industry
# 298    2007      1    MD                     Total Electric Power Industry
# 299    2007      1    MD                     Total Electric Power Industry
# 300    2007      1    MD           Electric Generators, Electric Utilities
# ...     ...    ...   ...                                               ...
# 41793  2011     12    MD  Electric Generators, Independent Power Producers
# 41794  2011     12    MD                     Total Electric Power Industry
# 41795  2011     12    MD                     Total Electric Power Industry
# 41796  2011     12    MD                     Total Electric Power Industry
# 41797  2011     12    MD                     Total Electric Power Industry
#
#                    ENERGY SOURCE  CONSUMPTION
# 296            Coal (Short Tons)   1095532.00
# 297          Petroleum (Barrels)    107089.00
# 298            Natural Gas (Mcf)    659234.00
# 299    Other Gases (Billion BTU)       356.46
# 300          Petroleum (Barrels)      2669.00
# ...                          ...          ...
# 41793        Petroleum (Barrels)     45889.00
# 41794          Coal (Short Tons)    553983.00
# 41795          Natural Gas (Mcf)    816158.00
# 41796  Other Gases (Billion Btu)       153.78
# 41797        Petroleum (Barrels)     47947.00
#
# [1129 rows x 6 columns]

# %%
df_md = pd.DataFrame()

for sheet in df_sheetnames:
    if sheet[0:2] == '20':
        print("Processing worksheet: ", sheet)
#         df_md = df_md.append(df_dict[sheet].loc[df_dict[sheet]["STATE"] == "MD"])  # .append method is deprecated
        df_sheet = df_dict[sheet].loc[df_dict[sheet]["STATE"] == "MD"]
        df_md = pd.concat([df_md, df_sheet])
# Out:
# Processing worksheet:  2001-2006_FINAL
# Processing worksheet:  2007-2011_FINAL
# Processing worksheet:  2012_Final
# Processing worksheet:  2013_Final
# Processing worksheet:  2014_Final
# Processing worksheet:  2015_Final
# Processing worksheet:  2016_Final
# Processing worksheet:  2017_Final
# Processing worksheet:  2018_Final
# Processing worksheet:  2019_Final
# Processing worksheet:  2020_Final
# Processing worksheet:  2021_Preliminary
# Processing worksheet:  2022_Preliminary

# %%
df_md
# Out:
#       YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 279   2001      1    MD                     Total Electric Power Industry
# 280   2001      1    MD                     Total Electric Power Industry
# 281   2001      1    MD                     Total Electric Power Industry
# 282   2001      1    MD                     Total Electric Power Industry
# 283   2001      1    MD           Electric Generators, Electric Utilities
# ...    ...    ...   ...                                               ...
# 4110  2022      6    MD  Electric Generators, Independent Power Producers
# 4111  2022      6    MD  Electric Generators, Independent Power Producers
# 4112  2022      6    MD  Electric Generators, Independent Power Producers
# 4113  2022      6    MD           Electric Generators, Electric Utilities
# 4114  2022      6    MD           Electric Generators, Electric Utilities
#
#                   ENERGY SOURCE CONSUMPTION
# 279           Coal (Short Tons)   1080740.0
# 280         Petroleum (Barrels)    681862.0
# 281           Natural Gas (Mcf)    420200.0
# 282   Other Gases (Billion BTU)       518.0
# 283         Petroleum (Barrels)     37102.0
# ...                         ...         ...
# 4110          Coal (Short Tons)      143592
# 4111          Natural Gas (Mcf)     7236472
# 4112        Petroleum (Barrels)       34075
# 4113          Natural Gas (Mcf)     3125789
# 4114        Petroleum (Barrels)         598
#
# [4502 rows x 6 columns]

# %%
len(df_md)
# Out:
# 4502

# %%
df_md.describe
# Out:
# <bound method NDFrame.describe of       YEAR  MONTH STATE                                  TYPE OF PRODUCER  \
# 279   2001      1    MD                     Total Electric Power Industry
# 280   2001      1    MD                     Total Electric Power Industry
# 281   2001      1    MD                     Total Electric Power Industry
# 282   2001      1    MD                     Total Electric Power Industry
# 283   2001      1    MD           Electric Generators, Electric Utilities
# ...    ...    ...   ...                                               ...
# 4110  2022      6    MD  Electric Generators, Independent Power Producers
# 4111  2022      6    MD  Electric Generators, Independent Power Producers
# 4112  2022      6    MD  Electric Generators, Independent Power Producers
# 4113  2022      6    MD           Electric Generators, Electric Utilities
# 4114  2022      6    MD           Electric Generators, Electric Utilities
#
#                   ENERGY SOURCE CONSUMPTION
# 279           Coal (Short Tons)   1080740.0
# 280         Petroleum (Barrels)    681862.0
# 281           Natural Gas (Mcf)    420200.0
# 282   Other Gases (Billion BTU)       518.0
# 283         Petroleum (Barrels)     37102.0
# ...                         ...         ...
# 4110          Coal (Short Tons)      143592
# 4111          Natural Gas (Mcf)     7236472
# 4112        Petroleum (Barrels)       34075
# 4113          Natural Gas (Mcf)     3125789
# 4114        Petroleum (Barrels)         598
#
# [4502 rows x 6 columns]>

# %%
df_md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4502 entries, 279 to 4114
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              4502 non-null   int64
#  1   MONTH             4502 non-null   int64
#  2   STATE             4502 non-null   object
#  3   TYPE OF PRODUCER  4502 non-null   object
#  4   ENERGY SOURCE     4502 non-null   object
#  5   CONSUMPTION       4502 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 246.2+ KB

# %%
df_md['TYPE OF PRODUCER'].unique()
# Out:
# array(['Total Electric Power Industry',
#        'Electric Generators, Electric Utilities',
#        'Electric Generators, Independent Power Producers',
#        'Combined Heat and Power, Electric Power',
#        'Combined Heat and Power, Commercial Power',
#        'Combined Heat and Power, Industrial Power'], dtype=object)

# %%
df_md.to_csv('consumption_monthly_md_221001.csv')

# %%
df_md['TYPE OF PRODUCER'].value_counts()
# Out:
# Total Electric Power Industry                       912
# Combined Heat and Power, Electric Power             894
# Electric Generators, Independent Power Producers    774
# Combined Heat and Power, Industrial Power           745
# Combined Heat and Power, Commercial Power           667
# Electric Generators, Electric Utilities             510
# Name: TYPE OF PRODUCER, dtype: int64

# %%
df_total_producer_md = df_md.loc[df_md['TYPE OF PRODUCER'] == 'Total Electric Power Industry']

# %%
df_total_producer_md
# Out:
#       YEAR  MONTH STATE               TYPE OF PRODUCER  \
# 279   2001      1    MD  Total Electric Power Industry
# 280   2001      1    MD  Total Electric Power Industry
# 281   2001      1    MD  Total Electric Power Industry
# 282   2001      1    MD  Total Electric Power Industry
# 1032  2001      2    MD  Total Electric Power Industry
# ...    ...    ...   ...                            ...
# 3337  2022      5    MD  Total Electric Power Industry
# 3338  2022      5    MD  Total Electric Power Industry
# 4099  2022      6    MD  Total Electric Power Industry
# 4100  2022      6    MD  Total Electric Power Industry
# 4101  2022      6    MD  Total Electric Power Industry
#
#                   ENERGY SOURCE CONSUMPTION
# 279           Coal (Short Tons)   1080740.0
# 280         Petroleum (Barrels)    681862.0
# 281           Natural Gas (Mcf)    420200.0
# 282   Other Gases (Billion BTU)       518.0
# 1032          Coal (Short Tons)    954720.0
# ...                         ...         ...
# 3337          Natural Gas (Mcf)     8437112
# 3338        Petroleum (Barrels)       13876
# 4099          Coal (Short Tons)      168559
# 4100          Natural Gas (Mcf)    11024527
# 4101        Petroleum (Barrels)       35964
#
# [912 rows x 6 columns]

# %%
year = 2012
month = 4
df_total_producer_md.loc[(df_total_producer_md['YEAR'] == year) & (df_total_producer_md['MONTH'] == month)]
# Out:
#       YEAR  MONTH STATE               TYPE OF PRODUCER  \
# 2621  2012      4    MD  Total Electric Power Industry
# 2622  2012      4    MD  Total Electric Power Industry
# 2623  2012      4    MD  Total Electric Power Industry
# 2624  2012      4    MD  Total Electric Power Industry
#
#                   ENERGY SOURCE CONSUMPTION
# 2621          Coal (Short Tons)      355541
# 2622          Natural Gas (Mcf)     9011642
# 2623  Other Gases (Billion Btu)      413.65
# 2624        Petroleum (Barrels)       19244

# %%
year = 2012
df_total_producer_md.loc[((df_total_producer_md['YEAR'] == year) & (df_total_producer_md['ENERGY SOURCE'] == 'Coal (Short Tons)'))]['CONSUMPTION'].sum()
# Out:
# 6981310

# %%
energy_sources = df_total_producer_md['ENERGY SOURCE'].unique()
for source in energy_sources:
    print("Total Consumption of ", source, " = ", df_total_producer_md.loc[df_total_producer_md['ENERGY SOURCE'] == source]['CONSUMPTION'].sum())
# Out:
# Total Consumtion of  Coal (Short Tons)  =  170193957.76999998
# Total Consumtion of  Petroleum (Barrels)  =  37866569.02
# Total Consumtion of  Natural Gas (Mcf)  =  927610512.51
# Total Consumtion of  Other Gases (Billion BTU)  =  51967.619999999995
# Total Consumtion of  Other Gases (Billion Btu)  =  3316.4600000000005

# %%
years = df_total_producer_md['YEAR'].unique()
for year in (years[:-1]):
    for month in range(1,13):
        monthly_consumption = df_total_producer_md.loc[(df_total_producer_md['YEAR'] == year) & (df_total_producer_md['MONTH'] == month) & (df_total_producer_md['ENERGY SOURCE'] == 'Coal (Short Tons)')]['CONSUMPTION'].sum()
        print(year,month, monthly_consumption)
#     print(year, df_total_producer_md['MONTH'])
# Out:
